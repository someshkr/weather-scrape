# %% [markdown]
# ## Welcome to your first casestudy
# - In this case study you have to scrape weather data from the website  **"http://www.estesparkweather.net/archive_reports.php?date=200901"**
# - Scrape all the available attributes of weather data for each day from **2009-01-01 to 2018-10-28**
# - Ignore records for missing days
# - Represent the scraped data as **pandas dataframe** object.

# %% [markdown]
# ### Dataframe specific deatails
# - Expected column names (order dose not matter):
#        ['Average temperature (°F)', 'Average humidity (%)',
#        'Average dewpoint (°F)', 'Average barometer (in)',
#        'Average windspeed (mph)', 'Average gustspeed (mph)',
#        'Average direction (°deg)', 'Rainfall for month (in)',
#        'Rainfall for year (in)', 'Maximum rain per minute',
#        'Maximum temperature (°F)', 'Minimum temperature (°F)',
#        'Maximum humidity (%)', 'Minimum humidity (%)', 'Maximum pressure',
#        'Minimum pressure', 'Maximum windspeed (mph)',
#        'Maximum gust speed (mph)', 'Maximum heat index (°F)']
# - Each record in the dataframe corresponds to weather deatils of a given day
# - Make sure the index column is **date-time format (yyyy-mm-dd)**
# - Perform necessary data cleaning and type cast each attributes to relevent data type

# %% [markdown]
# ### Saving the dataframe
# - Once you are done with you scrapping save your dataframe as pickle file by name 'dataframe.pk'
#
# #### Sample code to save pickle file
# ```python
# import pickle
# with open("dataframe.pk", "wb") as file:
#     pickle.dump(<your_dataframe>, file)
# ```

# %% [markdown]
# ### Run the below cell to import necessary packages
# - These packages should be sufficient to perform you task
# - In case if you are looking are any other packages run **!pip3 install <package_name> --user with in a cell**

# %%
import bs4
from bs4 import BeautifulSoup
import csv
import requests
import time
import pandas as pd
import urllib
import re
import pickle

# %%
#### Start you code here, you are free to add any number of cells
from datetime import datetime
Dates_r = pd.date_range(start = '1/1/2009',end = '10/28/2018',freq = 'M')
dates = [str(i)[:4] + str(i)[5:7] for i in Dates_r]
dates[0:5]

df_list = []
index = []
for k in range(len(dates)):
    url = "http://www.estesparkweather.net/archive_reports.php?date="
    url += dates[k]

# %%
page  = requests.get(url)
soup =  BeautifulSoup(page.content,'html.parser')

table = soup.find_all('table')
type(table)

raw_data = [row.text.splitlines() for row in table]
raw_data = raw_data[:-9] 
raw_data

for i in range(len(raw_data)):
  raw_data[i] = raw_data[i][2:len(raw_data[i]):3]
raw_data
# Out:
# [['Sep 1 Average and Extremes',
#   'Average temperature 61.2°F',
#   'Average humidity 34%',
#   'Average dewpoint 31.5°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 3.3 mph',
#   'Average gustspeed 5.0 mph',
#   'Average direction 281° (WNW)',
#   'Rainfall for month 0.00 in.',
#   'Rainfall for year 5.33 in.',
#   'Maximum rain per minute 0.00 in. on day 01 at time 00:00',
#   'Maximum temperature 77.7°F on day 01 at time 13:11',
#   'Minimum temperature 46.5°F on day 01 at time 06:54',
#   'Maximum humidity 55% on day 01 at time 23:27',
#   'Minimum humidity 21% on day 01 at time 18:32',
#   'Maximum pressure 29.733 in. on day 01 at time 23:12',
#   'Minimum pressure 29.496 in. on day 01 at time 13:05',
#   'Maximum windspeed 25.3 mph on day 01 at time 14:17',
#   'Maximum gust speed 29.9 mph  from 281 °( W ) on day 01 at time 14:51',
#   'Maximum heat index 77.7°F on day 01 at time 13:04'],
#  ['Sep 2 Average and Extremes',
#   'Average temperature 56.4°F',
#   'Average humidity 42%',
#   'Average dewpoint 31.2°F',
#   'Average barometer 29.8 in.',
#   'Average windspeed 2.3 mph',
#   'Average gustspeed 4.0 mph',
#   'Average direction 281° (WNW)',
#   'Rainfall for month 0.00 in.',
#   'Rainfall for year 5.33 in.',
#   'Maximum rain per minute 0.00 in. on day 02 at time 23:59',
#   'Maximum temperature 77.6°F on day 02 at time 15:40',
#   'Minimum temperature 37.5°F on day 02 at time 06:47',
#   'Maximum humidity 72% on day 02 at time 06:01',
#   'Minimum humidity 15% on day 02 at time 10:23',
#   'Maximum pressure 29.891 in. on day 02 at time 07:16',
#   'Minimum pressure 29.641 in. on day 02 at time 00:03',
#   'Maximum windspeed 12.7 mph on day 02 at time 12:38',
#   'Maximum gust speed 19.6 mph  from 281 °( W ) on day 02 at time 16:08',
#   'Maximum heat index 77.3°F on day 02 at time 15:40'],
#  ['Sep 3 Average and Extremes',
#   'Average temperature 56.0°F',
#   'Average humidity 47%',
#   'Average dewpoint 33.9°F',
#   'Average barometer 29.8 in.',
#   'Average windspeed 1.4 mph',
#   'Average gustspeed 2.5 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.00 in.',
#   'Rainfall for year 5.33 in.',
#   'Maximum rain per minute 0.00 in. on day 03 at time 23:59',
#   'Maximum temperature 73.2°F on day 03 at time 13:16',
#   'Minimum temperature 42.3°F on day 03 at time 04:41',
#   'Maximum humidity 71% on day 03 at time 05:55',
#   'Minimum humidity 16% on day 03 at time 12:56',
#   'Maximum pressure 29.884 in. on day 03 at time 07:16',
#   'Minimum pressure 29.685 in. on day 03 at time 23:28',
#   'Maximum windspeed 12.7 mph on day 03 at time 15:44',
#   'Maximum gust speed 18.4 mph  from 283 °(WNW) on day 03 at time 15:46',
#   'Maximum heat index 76.4°F on day 03 at time 11:19'],
#  ['Sep 4 Average and Extremes',
#   'Average temperature 54.0°F',
#   'Average humidity 60%',
#   'Average dewpoint 37.9°F',
#   'Average barometer 29.8 in.',
#   'Average windspeed 2.0 mph',
#   'Average gustspeed 3.4 mph',
#   'Average direction 281° (WNW)',
#   'Rainfall for month 0.21 in.',
#   'Rainfall for year 5.54 in.',
#   'Maximum rain per minute 0.03 in. on day 04 at time 15:08',
#   'Maximum temperature 74.9°F on day 04 at time 11:50',
#   'Minimum temperature 41.1°F on day 04 at time 03:40',
#   'Maximum humidity 85% on day 04 at time 23:59',
#   'Minimum humidity 19% on day 04 at time 13:48',
#   'Maximum pressure 29.996 in. on day 04 at time 15:44',
#   'Minimum pressure 29.675 in. on day 04 at time 00:21',
#   'Maximum windspeed 20.7 mph on day 04 at time 15:06',
#   'Maximum gust speed 31.1 mph  from 281 °( W ) on day 04 at time 15:26',
#   'Maximum heat index 76.9°F on day 04 at time 14:35'],
#  ['Sep 5 Average and Extremes',
#   'Average temperature 53.8°F',
#   'Average humidity 72%',
#   'Average dewpoint 44.7°F',
#   'Average barometer 30.0 in.',
#   'Average windspeed 2.3 mph',
#   'Average gustspeed 3.9 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.21 in.',
#   'Rainfall for year 5.54 in.',
#   'Maximum rain per minute 0.00 in. on day 05 at time 23:59',
#   'Maximum temperature 65.6°F on day 05 at time 16:05',
#   'Minimum temperature 47.0°F on day 05 at time 23:59',
#   'Maximum humidity 88% on day 05 at time 06:48',
#   'Minimum humidity 49% on day 05 at time 12:00',
#   'Maximum pressure 30.100 in. on day 05 at time 21:01',
#   'Minimum pressure 29.869 in. on day 05 at time 00:43',
#   'Maximum windspeed 13.8 mph on day 05 at time 13:04',
#   'Maximum gust speed 16.1 mph  from 284 °(WNW) on day 05 at time 16:33',
#   'Maximum heat index 65.6°F on day 05 at time 16:05'],
#  ['Sep 6 Average and Extremes',
#   'Average temperature 51.8°F',
#   'Average humidity 74%',
#   'Average dewpoint 43.0°F',
#   'Average barometer 30.1 in.',
#   'Average windspeed 1.7 mph',
#   'Average gustspeed 2.9 mph',
#   'Average direction 283° (WNW)',
#   'Rainfall for month 0.65 in.',
#   'Rainfall for year 5.98 in.',
#   'Maximum rain per minute 0.14 in. on day 06 at time 13:24',
#   'Maximum temperature 68.1°F on day 06 at time 11:56',
#   'Minimum temperature 40.2°F on day 06 at time 05:49',
#   'Maximum humidity 92% on day 06 at time 08:03',
#   'Minimum humidity 41% on day 06 at time 11:51',
#   'Maximum pressure 30.218 in. on day 06 at time 14:04',
#   'Minimum pressure 29.958 in. on day 06 at time 22:18',
#   'Maximum windspeed 13.8 mph on day 06 at time 13:29',
#   'Maximum gust speed 20.7 mph  from 284 °(WNW) on day 06 at time 13:27',
#   'Maximum heat index 77.5°F on day 06 at time 11:55'],
#  ['Sep 7 Average and Extremes',
#   'Average temperature 53.0°F',
#   'Average humidity 70%',
#   'Average dewpoint 41.8°F',
#   'Average barometer 30.0 in.',
#   'Average windspeed 1.9 mph',
#   'Average gustspeed 3.5 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.01 in. on day 07 at time 03:27',
#   'Maximum temperature 70.1°F on day 07 at time 14:55',
#   'Minimum temperature 34.4°F on day 07 at time 06:54',
#   'Maximum humidity 93% on day 07 at time 07:58',
#   'Minimum humidity 34% on day 07 at time 12:36',
#   'Maximum pressure 30.264 in. on day 07 at time 02:57',
#   'Minimum pressure 29.909 in. on day 07 at time 23:04',
#   'Maximum windspeed 16.1 mph on day 07 at time 13:13',
#   'Maximum gust speed 19.6 mph  from 281 °( W ) on day 07 at time 13:26',
#   'Maximum heat index 77.5°F on day 07 at time 15:51'],
#  ['Sep 8 Average and Extremes',
#   'Average temperature 57.7°F',
#   'Average humidity 55%',
#   'Average dewpoint 37.8°F',
#   'Average barometer 29.8 in.',
#   'Average windspeed 2.5 mph',
#   'Average gustspeed 4.2 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 08 at time 23:59',
#   'Maximum temperature 75.8°F on day 08 at time 12:06',
#   'Minimum temperature 37.9°F on day 08 at time 06:56',
#   'Maximum humidity 94% on day 08 at time 07:54',
#   'Minimum humidity 17% on day 08 at time 12:02',
#   'Maximum pressure 30.024 in. on day 08 at time 07:03',
#   'Minimum pressure 29.585 in. on day 08 at time 23:07',
#   'Maximum windspeed 16.1 mph on day 08 at time 21:32',
#   'Maximum gust speed 26.5 mph  from 283 °(WNW) on day 08 at time 22:01',
#   'Maximum heat index 76.8°F on day 08 at time 10:36'],
#  ['Sep 9 Average and Extremes',
#   'Average temperature 62.8°F',
#   'Average humidity 36%',
#   'Average dewpoint 33.5°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 3.3 mph',
#   'Average gustspeed 5.1 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 09 at time 23:59',
#   'Maximum temperature 77.2°F on day 09 at time 13:20',
#   'Minimum temperature 46.4°F on day 09 at time 23:59',
#   'Maximum humidity 58% on day 09 at time 07:11',
#   'Minimum humidity 17% on day 09 at time 14:32',
#   'Maximum pressure 29.768 in. on day 09 at time 07:14',
#   'Minimum pressure 29.545 in. on day 09 at time 14:27',
#   'Maximum windspeed 15.0 mph on day 09 at time 09:38',
#   'Maximum gust speed 26.5 mph  from 280 °( W ) on day 09 at time 13:32',
#   'Maximum heat index 77.1°F on day 09 at time 13:19'],
#  ['Sep 10 Average and Extremes',
#   'Average temperature 59.5°F',
#   'Average humidity 37%',
#   'Average dewpoint 28.3°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 1.9 mph',
#   'Average gustspeed 3.2 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 10 at time 23:59',
#   'Maximum temperature 87.2°F on day 10 at time 15:23',
#   'Minimum temperature 36.6°F on day 10 at time 06:51',
#   'Maximum humidity 71% on day 10 at time 05:50',
#   'Minimum humidity 7% on day 10 at time 15:36',
#   'Maximum pressure 29.877 in. on day 10 at time 07:07',
#   'Minimum pressure 29.590 in. on day 10 at time 15:31',
#   'Maximum windspeed 13.8 mph on day 10 at time 12:17',
#   'Maximum gust speed 19.6 mph  from 281 °( W ) on day 10 at time 13:31',
#   'Maximum heat index 83.7°F on day 10 at time 15:23'],
#  ['Sep 13 Average and Extremes',
#   'Average temperature 73.4°F',
#   'Average humidity 10%',
#   'Average dewpoint 12.5°F',
#   'Average barometer 29.5 in.',
#   'Average windspeed 7.4 mph',
#   'Average gustspeed 11.0 mph',
#   'Average direction 281° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 13 at time 23:59',
#   'Maximum temperature 83.2°F on day 13 at time 15:20',
#   'Minimum temperature 56.5°F on day 13 at time 05:27',
#   'Maximum humidity 22% on day 13 at time 06:03',
#   'Minimum humidity 6% on day 13 at time 18:38',
#   'Maximum pressure 29.595 in. on day 13 at time 05:00',
#   'Minimum pressure 29.413 in. on day 13 at time 14:41',
#   'Maximum windspeed 19.6 mph on day 13 at time 11:41',
#   'Maximum gust speed 26.5 mph  from 280 °( W ) on day 13 at time 14:22',
#   'Maximum heat index 80.5°F on day 13 at time 15:14'],
#  ['Sep 14 Average and Extremes',
#   'Average temperature 69.1°F',
#   'Average humidity 12%',
#   'Average dewpoint 12.2°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 5.2 mph',
#   'Average gustspeed 8.4 mph',
#   'Average direction 281° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 14 at time 23:59',
#   'Maximum temperature 81.6°F on day 14 at time 13:12',
#   'Minimum temperature 49.2°F on day 14 at time 23:59',
#   'Maximum humidity 35% on day 14 at time 23:54',
#   'Minimum humidity 5% on day 14 at time 12:44',
#   'Maximum pressure 29.754 in. on day 14 at time 22:54',
#   'Minimum pressure 29.499 in. on day 14 at time 00:51',
#   'Maximum windspeed 17.3 mph on day 14 at time 10:27',
#   'Maximum gust speed 19.6 mph  from 280 °( W ) on day 14 at time 11:56',
#   'Maximum heat index 79.3°F on day 14 at time 13:10'],
#  ['Sep 15 Average and Extremes',
#   'Average temperature 63.1°F',
#   'Average humidity 25%',
#   'Average dewpoint 22.9°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 2.6 mph',
#   'Average gustspeed 4.5 mph',
#   'Average direction 281° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 15 at time 23:59',
#   'Maximum temperature 81.8°F on day 15 at time 12:28',
#   'Minimum temperature 40.9°F on day 15 at time 04:45',
#   'Maximum humidity 54% on day 15 at time 04:34',
#   'Minimum humidity 9% on day 15 at time 12:30',
#   'Maximum pressure 29.846 in. on day 15 at time 07:11',
#   'Minimum pressure 29.562 in. on day 15 at time 20:03',
#   'Maximum windspeed 11.5 mph on day 15 at time 11:52',
#   'Maximum gust speed 17.3 mph  from 283 °(WNW) on day 15 at time 12:58',
#   'Maximum heat index 79.4°F on day 15 at time 12:26'],
#  ['Sep 16 Average and Extremes',
#   'Average temperature 64.8°F',
#   'Average humidity 29%',
#   'Average dewpoint 28.3°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 4.0 mph',
#   'Average gustspeed 6.2 mph',
#   'Average direction 280° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 16 at time 23:59',
#   'Maximum temperature 83.8°F on day 16 at time 15:53',
#   'Minimum temperature 43.5°F on day 16 at time 04:05',
#   'Maximum humidity 57% on day 16 at time 06:05',
#   'Minimum humidity 10% on day 16 at time 17:25',
#   'Maximum pressure 29.807 in. on day 16 at time 07:08',
#   'Minimum pressure 29.511 in. on day 16 at time 20:12',
#   'Maximum windspeed 18.4 mph on day 16 at time 11:25',
#   'Maximum gust speed 24.2 mph  from 281 °( W ) on day 16 at time 13:51',
#   'Maximum heat index 80.9°F on day 16 at time 15:53'],
#  ['Sep 17 Average and Extremes',
#   'Average temperature 64.8°F',
#   'Average humidity 31%',
#   'Average dewpoint 31.4°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 2.9 mph',
#   'Average gustspeed 4.8 mph',
#   'Average direction 281° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 17 at time 23:59',
#   'Maximum temperature 82.4°F on day 17 at time 16:02',
#   'Minimum temperature 48.2°F on day 17 at time 03:47',
#   'Maximum humidity 51% on day 17 at time 06:13',
#   'Minimum humidity 15% on day 17 at time 16:02',
#   'Maximum pressure 29.736 in. on day 17 at time 07:10',
#   'Minimum pressure 29.534 in. on day 17 at time 20:10',
#   'Maximum windspeed 18.4 mph on day 17 at time 13:11',
#   'Maximum gust speed 20.7 mph  from 281 °( W ) on day 17 at time 13:12',
#   'Maximum heat index 79.9°F on day 17 at time 16:02'],
#  ['Sep 18 Average and Extremes',
#   'Average temperature 62.4°F',
#   'Average humidity 42%',
#   'Average dewpoint 35.2°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 3.7 mph',
#   'Average gustspeed 5.8 mph',
#   'Average direction 281° ( W )',
#   'Rainfall for month 0.66 in.',
#   'Rainfall for year 5.99 in.',
#   'Maximum rain per minute 0.00 in. on day 18 at time 23:59',
#   'Maximum temperature 83.6°F on day 18 at time 15:20',
#   'Minimum temperature 41.5°F on day 18 at time 07:08',
#   'Maximum humidity 74% on day 18 at time 07:16',
#   'Minimum humidity 12% on day 18 at time 14:24',
#   'Maximum pressure 29.802 in. on day 18 at time 07:18',
#   'Minimum pressure 29.497 in. on day 18 at time 14:58',
#   'Maximum windspeed 21.9 mph on day 18 at time 13:19',
#   'Maximum gust speed 29.9 mph  from 284 °(WNW) on day 18 at time 13:19',
#   'Maximum heat index 80.8°F on day 18 at time 15:20'],
#  ['Sep 19 Average and Extremes',
#   'Average temperature 61.0°F',
#   'Average humidity 43%',
#   'Average dewpoint 35.4°F',
#   'Average barometer 29.5 in.',
#   'Average windspeed 4.1 mph',
#   'Average gustspeed 6.6 mph',
#   'Average direction 281° (WNW)',
#   'Rainfall for month 0.67 in.',
#   'Rainfall for year 6.00 in.',
#   'Maximum rain per minute 0.01 in. on day 19 at time 17:29',
#   'Maximum temperature 79.6°F on day 19 at time 12:15',
#   'Minimum temperature 45.2°F on day 19 at time 03:53',
#   'Maximum humidity 77% on day 19 at time 23:59',
#   'Minimum humidity 12% on day 19 at time 12:24',
#   'Maximum pressure 29.656 in. on day 19 at time 17:01',
#   'Minimum pressure 29.401 in. on day 19 at time 23:59',
#   'Maximum windspeed 18.4 mph on day 19 at time 16:56',
#   'Maximum gust speed 26.5 mph  from 281 °( W ) on day 19 at time 16:44',
#   'Maximum heat index 78.2°F on day 19 at time 12:14'],
#  ['Sep 20 Average and Extremes',
#   'Average temperature 60.1°F',
#   'Average humidity 37%',
#   'Average dewpoint 28.4°F',
#   'Average barometer 29.5 in.',
#   'Average windspeed 4.9 mph',
#   'Average gustspeed 8.1 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.67 in.',
#   'Rainfall for year 6.00 in.',
#   'Maximum rain per minute 0.00 in. on day 20 at time 23:59',
#   'Maximum temperature 72.7°F on day 20 at time 13:47',
#   'Minimum temperature 47.0°F on day 20 at time 23:59',
#   'Maximum humidity 80% on day 20 at time 01:13',
#   'Minimum humidity 11% on day 20 at time 18:03',
#   'Maximum pressure 29.866 in. on day 20 at time 23:59',
#   'Minimum pressure 29.398 in. on day 20 at time 00:01',
#   'Maximum windspeed 20.7 mph on day 20 at time 11:55',
#   'Maximum gust speed 33.4 mph  from 283 °(WNW) on day 20 at time 11:55',
#   'Maximum heat index 74.8°F on day 20 at time 12:57'],
#  ['Sep 21 Average and Extremes',
#   'Average temperature 50.2°F',
#   'Average humidity 58%',
#   'Average dewpoint 34.3°F',
#   'Average barometer 30.0 in.',
#   'Average windspeed 2.3 mph',
#   'Average gustspeed 4.0 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.67 in.',
#   'Rainfall for year 6.00 in.',
#   'Maximum rain per minute 0.00 in. on day 21 at time 23:59',
#   'Maximum temperature 68.4°F on day 21 at time 14:39',
#   'Minimum temperature 31.0°F on day 21 at time 07:12',
#   'Maximum humidity 86% on day 21 at time 07:36',
#   'Minimum humidity 33% on day 21 at time 16:16',
#   'Maximum pressure 30.134 in. on day 21 at time 07:17',
#   'Minimum pressure 29.808 in. on day 21 at time 00:03',
#   'Maximum windspeed 12.7 mph on day 21 at time 15:14',
#   'Maximum gust speed 18.4 mph  from 283 °(WNW) on day 21 at time 14:51',
#   'Maximum heat index 76.9°F on day 21 at time 14:34'],
#  ['Sep 22 Average and Extremes',
#   'Average temperature 55.6°F',
#   'Average humidity 33%',
#   'Average dewpoint 17.3°F',
#   'Average barometer 29.9 in.',
#   'Average windspeed 3.7 mph',
#   'Average gustspeed 5.8 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.67 in.',
#   'Rainfall for year 6.00 in.',
#   'Maximum rain per minute 0.00 in. on day 22 at time 23:59',
#   'Maximum temperature 77.0°F on day 22 at time 15:18',
#   'Minimum temperature 31.8°F on day 22 at time 05:18',
#   'Maximum humidity 80% on day 22 at time 05:09',
#   'Minimum humidity 8% on day 22 at time 16:58',
#   'Maximum pressure 30.094 in. on day 22 at time 07:04',
#   'Minimum pressure 29.719 in. on day 22 at time 20:07',
#   'Maximum windspeed 17.3 mph on day 22 at time 13:43',
#   'Maximum gust speed 25.3 mph  from 281 °( W ) on day 22 at time 11:54',
#   'Maximum heat index 75.8°F on day 22 at time 15:18'],
#  ['Sep 23 Average and Extremes',
#   'Average temperature 57.5°F',
#   'Average humidity 25%',
#   'Average dewpoint 20.2°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 3.6 mph',
#   'Average gustspeed 5.7 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.67 in.',
#   'Rainfall for year 6.00 in.',
#   'Maximum rain per minute 0.00 in. on day 23 at time 23:59',
#   'Maximum temperature 75.8°F on day 23 at time 15:27',
#   'Minimum temperature 36.8°F on day 23 at time 04:29',
#   'Maximum humidity 47% on day 23 at time 05:59',
#   'Minimum humidity 13% on day 23 at time 17:01',
#   'Maximum pressure 29.906 in. on day 23 at time 07:22',
#   'Minimum pressure 29.517 in. on day 23 at time 22:06',
#   'Maximum windspeed 19.6 mph on day 23 at time 16:55',
#   'Maximum gust speed 29.9 mph  from 283 °(WNW) on day 23 at time 12:59',
#   'Maximum heat index 75.8°F on day 23 at time 15:24'],
#  ['Sep 24 Average and Extremes',
#   'Average temperature 55.5°F',
#   'Average humidity 41%',
#   'Average dewpoint 31.1°F',
#   'Average barometer 29.6 in.',
#   'Average windspeed 6.8 mph',
#   'Average gustspeed 10.0 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.01 in. on day 24 at time 08:38',
#   'Maximum temperature 68.1°F on day 24 at time 13:31',
#   'Minimum temperature 44.6°F on day 24 at time 23:40',
#   'Maximum humidity 69% on day 24 at time 08:48',
#   'Minimum humidity 20% on day 24 at time 13:35',
#   'Maximum pressure 29.695 in. on day 24 at time 20:57',
#   'Minimum pressure 29.414 in. on day 24 at time 04:12',
#   'Maximum windspeed 25.3 mph on day 24 at time 13:43',
#   'Maximum gust speed 34.5 mph  from 281 °( W ) on day 24 at time 13:57',
#   'Maximum heat index 73.8°F on day 24 at time 13:31'],
#  ['Sep 25 Average and Extremes',
#   'Average temperature 47.6°F',
#   'Average humidity 40%',
#   'Average dewpoint 22.8°F',
#   'Average barometer 29.9 in.',
#   'Average windspeed 4.5 mph',
#   'Average gustspeed 7.4 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 25 at time 23:59',
#   'Maximum temperature 59.2°F on day 25 at time 14:34',
#   'Minimum temperature 35.6°F on day 25 at time 07:07',
#   'Maximum humidity 70% on day 25 at time 07:54',
#   'Minimum humidity 18% on day 25 at time 06:05',
#   'Maximum pressure 30.158 in. on day 25 at time 21:01',
#   'Minimum pressure 29.618 in. on day 25 at time 00:06',
#   'Maximum windspeed 19.6 mph on day 25 at time 05:38',
#   'Maximum gust speed 27.6 mph  from 283 °(WNW) on day 25 at time 03:04',
#   'Maximum heat index 59.2°F on day 25 at time 14:34'],
#  ['Sep 26 Average and Extremes',
#   'Average temperature 48.1°F',
#   'Average humidity 39%',
#   'Average dewpoint 17.2°F',
#   'Average barometer 30.0 in.',
#   'Average windspeed 2.2 mph',
#   'Average gustspeed 3.9 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 26 at time 23:59',
#   'Maximum temperature 69.1°F on day 26 at time 15:51',
#   'Minimum temperature 26.1°F on day 26 at time 05:53',
#   'Maximum humidity 86% on day 26 at time 07:55',
#   'Minimum humidity 7% on day 26 at time 16:02',
#   'Maximum pressure 30.248 in. on day 26 at time 07:43',
#   'Minimum pressure 29.739 in. on day 26 at time 23:04',
#   'Maximum windspeed 11.5 mph on day 26 at time 20:54',
#   'Maximum gust speed 18.4 mph  from 283 °(WNW) on day 26 at time 12:09',
#   'Maximum heat index 70.7°F on day 26 at time 15:53'],
#  ['Sep 27 Average and Extremes',
#   'Average temperature 58.0°F',
#   'Average humidity 18%',
#   'Average dewpoint 14.2°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 5.3 mph',
#   'Average gustspeed 8.5 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 27 at time 23:59',
#   'Maximum temperature 73.5°F on day 27 at time 13:56',
#   'Minimum temperature 42.5°F on day 27 at time 23:59',
#   'Maximum humidity 38% on day 27 at time 23:59',
#   'Minimum humidity 12% on day 27 at time 13:26',
#   'Maximum pressure 29.829 in. on day 27 at time 07:33',
#   'Minimum pressure 29.552 in. on day 27 at time 14:35',
#   'Maximum windspeed 15.0 mph on day 27 at time 15:44',
#   'Maximum gust speed 21.9 mph  from 281 °( W ) on day 27 at time 16:53',
#   'Maximum heat index 74.5°F on day 27 at time 13:55'],
#  ['Sep 28 Average and Extremes',
#   'Average temperature 39.4°F',
#   'Average humidity 71%',
#   'Average dewpoint 30.3°F',
#   'Average barometer 29.9 in.',
#   'Average windspeed 2.3 mph',
#   'Average gustspeed 4.3 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 28 at time 23:59',
#   'Maximum temperature 47.6°F on day 28 at time 10:29',
#   'Minimum temperature 30.9°F on day 28 at time 05:50',
#   'Maximum humidity 86% on day 28 at time 07:19',
#   'Minimum humidity 38% on day 28 at time 00:00',
#   'Maximum pressure 30.089 in. on day 28 at time 13:04',
#   'Minimum pressure 29.746 in. on day 28 at time 00:03',
#   'Maximum windspeed 12.7 mph on day 28 at time 11:21',
#   'Maximum gust speed 18.4 mph  from 283 °(WNW) on day 28 at time 11:19',
#   'Maximum heat index 47.6°F on day 28 at time 10:29'],
#  ['Sep 29 Average and Extremes',
#   'Average temperature 57.6°F',
#   'Average humidity 33%',
#   'Average dewpoint 20.9°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 4.9 mph',
#   'Average gustspeed 7.2 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 29 at time 23:59',
#   'Maximum temperature 78.3°F on day 29 at time 14:44',
#   'Minimum temperature 33.4°F on day 29 at time 01:05',
#   'Maximum humidity 88% on day 29 at time 02:30',
#   'Minimum humidity 9% on day 29 at time 15:52',
#   'Maximum pressure 29.980 in. on day 29 at time 00:32',
#   'Minimum pressure 29.484 in. on day 29 at time 15:24',
#   'Maximum windspeed 21.9 mph on day 29 at time 15:46',
#   'Maximum gust speed 28.8 mph  from 283 °(WNW) on day 29 at time 12:35',
#   'Maximum heat index 76.8°F on day 29 at time 14:40'],
#  ['Sep 30 Average and Extremes',
#   'Average temperature 53.7°F',
#   'Average humidity 46%',
#   'Average dewpoint 28.6°F',
#   'Average barometer 29.7 in.',
#   'Average windspeed 4.9 mph',
#   'Average gustspeed 6.9 mph',
#   'Average direction 282° (WNW)',
#   'Rainfall for month 0.68 in.',
#   'Rainfall for year 6.01 in.',
#   'Maximum rain per minute 0.00 in. on day 30 at time 23:59',
#   'Maximum temperature 75.8°F on day 30 at time 15:23',
#   'Minimum temperature 39.6°F on day 30 at time 23:41',
#   'Maximum humidity 80% on day 30 at time 22:01',
#   'Minimum humidity 7% on day 30 at time 15:12',
#   'Maximum pressure 29.840 in. on day 30 at time 20:01',
#   'Minimum pressure 29.440 in. on day 30 at time 23:59',
#   'Maximum windspeed 20.7 mph on day 30 at time 15:08',
#   'Maximum gust speed 32.2 mph  from 281 °( W ) on day 30 at time 15:29',
#   'Maximum heat index 76.5°F on day 30 at time 15:00']]

# %%
for u in url:
    for i in range(len(raw_data)):
        c = ['.'.join(re.findall("\d+",str(raw_data[i][j].split()[:5])))for j in range(len(raw_data[i]))]
        df_list.append(c)
        index.append(dates[k] + c[0])
    f_index = [index[i] for i in range(len(index)) if len(index[i]) > 6]
    data = [df_list[i][1:] for i in range(len(df_list)) if len(df_list[i][1:]) == 19]

from datetime import datetime
final_index = [datetime.strptime(str(f_index[i]), '%Y%m%d').strftime('%Y-%m-%d') for i in range(len(f_index))]

col = ['Average temperature (°F)', 'Average humidity (%)',
'Average dewpoint (°F)', 'Average barometer (in)',
'Average windspeed (mph)', 'Average gustspeed (mph)',
'Average direction (°deg)', 'Rainfall for month (in)',
'Rainfall for year (in)', 'Maximum rain per minute',
'Maximum temperature (°F)', 'Minimum temperature (°F)',
'Maximum humidity (%)', 'Minimum humidity (%)', 'Maximum pressure',
'Minimum pressure', 'Maximum windspeed (mph)',
'Maximum gust speed (mph)', 'Maximum heat index (°F)']
df = pd.DataFrame(data, columns = col, index = final_index)
df.head()
# Out:
#            Average temperature (°F) Average humidity (%)  \
# 2018-09-01                     61.2                   34
# 2018-09-02                     56.4                   42
# 2018-09-03                     56.0                   47
# 2018-09-04                     54.0                   60
# 2018-09-05                     53.8                   72
#
#            Average dewpoint (°F) Average barometer (in)  \
# 2018-09-01                  31.5                   29.6
# 2018-09-02                  31.2                   29.8
# 2018-09-03                  33.9                   29.8
# 2018-09-04                  37.9                   29.8
# 2018-09-05                  44.7                   30.0
#
#            Average windspeed (mph) Average gustspeed (mph)  \
# 2018-09-01                     3.3                     5.0
# 2018-09-02                     2.3                     4.0
# 2018-09-03                     1.4                     2.5
# 2018-09-04                     2.0                     3.4
# 2018-09-05                     2.3                     3.9
#
#            Average direction (°deg) Rainfall for month (in)  \
# 2018-09-01                      281                    0.00
# 2018-09-02                      281                    0.00
# 2018-09-03                      282                    0.00
# 2018-09-04                      281                    0.21
# 2018-09-05                      282                    0.21
#
#            Rainfall for year (in) Maximum rain per minute  \
# 2018-09-01                   5.33                    0.00
# 2018-09-02                   5.33                    0.00
# 2018-09-03                   5.33                    0.00
# 2018-09-04                   5.54                    0.03
# 2018-09-05                   5.54                    0.00
#
#            Maximum temperature (°F) Minimum temperature (°F)  \
# 2018-09-01                     77.7                     46.5
# 2018-09-02                     77.6                     37.5
# 2018-09-03                     73.2                     42.3
# 2018-09-04                     74.9                     41.1
# 2018-09-05                     65.6                     47.0
#
#            Maximum humidity (%) Minimum humidity (%) Maximum pressure  \
# 2018-09-01                   55                   21           29.733
# 2018-09-02                   72                   15           29.891
# 2018-09-03                   71                   16           29.884
# 2018-09-04                   85                   19           29.996
# 2018-09-05                   88                   49           30.100
#
#            Minimum pressure Maximum windspeed (mph) Maximum gust speed (mph)  \
# 2018-09-01           29.496                    25.3                     29.9
# 2018-09-02           29.641                    12.7                     19.6
# 2018-09-03           29.685                    12.7                     18.4
# 2018-09-04           29.675                    20.7                     31.1
# 2018-09-05           29.869                    13.8                     16.1
#
#            Maximum heat index (°F)
# 2018-09-01                    77.7
# 2018-09-02                    77.3
# 2018-09-03                    76.4
# 2018-09-04                    76.9
# 2018-09-05                    65.6
